# %% [markdown]
# <a href="https://colab.research.google.com/github/dominiksakic/deeplearning00/blob/main/generalWorkflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot from 2025-02-26 20-39-42.png](data:image/png;base64,...)

# %% [markdown]
# *   What is the Problem?
# *   Is there a old Solution to the Problem?
# *   What is the existing workflow?
# *   Is there any enviromental constraints? (on Device, etc.)

# %% [markdown]
# ![Screenshot from 2025-02-26 20-40-42.png](data:image/png;base64,...)

# %% [markdown]
# *   What are the inputs?
# *   What are the targets?
# *   What kind of ML Problem is it?
# *   How do existing solutions handle this type of Problem?
# *   Is Machine Learning really necessary?

# %% [markdown]
# # From then on there is two Hypothesis that have to revisted again and again!
#
# 1.   The Targets can be predicted by the Inputs (The latent Manifold exists)
# 2.   The Data is enough to learn the relationhip (Dense Sampling)

# %% [markdown]
# ![Screenshot from 2025-02-26 20-41-34.png](data:image/png;base64,...)

# %% [markdown]
# *   Is a SME Person needed, to label the Data?
# *   Can the labeling process be taught?
# *   Do I understand how the targets are put on the Data (if not, the Data will be a blackbox)?
# *   Is the data representative of the production data (CARDINAL SIN, if not!)?
# *   Is the data biased?
# *   Are there any information leakage?
# *   Can I visualize the data to gain insights?

# %% [markdown]
# ![Screenshot from 2025-02-26 20-42-06.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-02-26 20-42-50.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-02-26 20-43-32.png](data:image/png;base64,...)
